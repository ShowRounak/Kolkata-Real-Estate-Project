# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from sklearn.decomposition import PCA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7512\1589363284.py in <module>
#      11 from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor
#      12 from sklearn.neural_network import MLPRegressor
# ---> 13 from xgboost import XGBRegressor
#      14
#      15 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
#!pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.0.3-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages (from xgboost) (1.23.4)
# Requirement already satisfied: scipy in c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages (from xgboost) (1.11.3)
# Downloading xgboost-2.0.3-py3-none-win_amd64.whl (99.8 MB)
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/99.8 MB 1.3 MB/s eta 0:01:16
#    ---------------------------------------- 0.2/99.8 MB 1.5 MB/s eta 0:01:07
#    ---------------------------------------- 0.2/99.8 MB 1.4 MB/s eta 0:01:09
#    ---------------------------------------- 0.3/99.8 MB 1.5 MB/s eta 0:01:06
#    ---------------------------------------- 0.4/99.8 MB 1.7 MB/s eta 0:01:00
#    ---------------------------------------- 0.5/99.8 MB 1.7 MB/s eta 0:01:00
#    ---------------------------------------- 0.6/99.8 MB 1.7 MB/s eta 0:01:00
#    ---------------------------------------- 0.7/99.8 MB 1.7 MB/s eta 0:00:59
#    ---------------------------------------- 0.8/99.8 MB 1.7 MB/s eta 0:00:58
#    ---------------------------------------- 0.8/99.8 MB 1.7 MB/s eta 0:00:58
#    ---------------------------------------- 0.9/99.8 MB 1.7 MB/s eta 0:00:58
#    ---------------------------------------- 1.0/99.8 MB 1.8 MB/s eta 0:00:57
#    ---------------------------------------- 1.1/99.8 MB 1.8 MB/s eta 0:00:56
#    ---------------------------------------- 1.2/99.8 MB 1.8 MB/s eta 0:00:55
#     --------------------------------------- 1.3/99.8 MB 1.8 MB/s eta 0:00:54
#     --------------------------------------- 1.4/99.8 MB 1.8 MB/s eta 0:00:54
#     --------------------------------------- 1.5/99.8 MB 1.8 MB/s eta 0:00:54
#     --------------------------------------- 1.6/99.8 MB 1.9 MB/s eta 0:00:53
#     --------------------------------------- 1.7/99.8 MB 1.9 MB/s eta 0:00:52
#     --------------------------------------- 1.8/99.8 MB 1.9 MB/s eta 0:00:52
#     --------------------------------------- 1.9/99.8 MB 1.9 MB/s eta 0:00:52
#     --------------------------------------- 2.0/99.8 MB 1.9 MB/s eta 0:00:51
#     --------------------------------------- 2.1/99.8 MB 2.0 MB/s eta 0:00:50
#     --------------------------------------- 2.1/99.8 MB 2.0 MB/s eta 0:00:50
#     --------------------------------------- 2.1/99.8 MB 2.0 MB/s eta 0:00:50
#     --------------------------------------- 2.1/99.8 MB 2.0 MB/s eta 0:00:50
#     --------------------------------------- 2.2/99.8 MB 1.7 MB/s eta 0:00:59
#     --------------------------------------- 2.3/99.8 MB 1.7 MB/s eta 0:00:58
#     --------------------------------------- 2.4/99.8 MB 1.7 MB/s eta 0:00:57
#    - -------------------------------------- 2.5/99.8 MB 1.8 MB/s eta 0:00:56
#    - -------------------------------------- 2.6/99.8 MB 1.8 MB/s eta 0:00:55
#    - -------------------------------------- 2.8/99.8 MB 1.8 MB/s eta 0:00:54
#    - -------------------------------------- 2.9/99.8 MB 1.8 MB/s eta 0:00:54
#    - -------------------------------------- 3.0/99.8 MB 1.8 MB/s eta 0:00:53
#    - -------------------------------------- 3.1/99.8 MB 1.9 MB/s eta 0:00:52
#    - -------------------------------------- 3.3/99.8 MB 1.9 MB/s eta 0:00:51
#    - -------------------------------------- 3.4/99.8 MB 1.9 MB/s eta 0:00:51
#    - -------------------------------------- 3.5/99.8 MB 2.0 MB/s eta 0:00:50
#    - -------------------------------------- 3.7/99.8 MB 2.0 MB/s eta 0:00:49
#    - -------------------------------------- 3.8/99.8 MB 2.0 MB/s eta 0:00:48
#    - -------------------------------------- 4.0/99.8 MB 2.0 MB/s eta 0:00:48
#    - -------------------------------------- 4.1/99.8 MB 2.0 MB/s eta 0:00:47
#    - -------------------------------------- 4.2/99.8 MB 2.1 MB/s eta 0:00:47
#    - -------------------------------------- 4.4/99.8 MB 2.1 MB/s eta 0:00:46
#    - -------------------------------------- 4.5/99.8 MB 2.1 MB/s eta 0:00:46
#    - -------------------------------------- 4.7/99.8 MB 2.1 MB/s eta 0:00:45
#    - -------------------------------------- 4.8/99.8 MB 2.1 MB/s eta 0:00:45
#    - -------------------------------------- 4.9/99.8 MB 2.1 MB/s eta 0:00:45
#    -- ------------------------------------- 5.0/99.8 MB 2.2 MB/s eta 0:00:44
#    -- ------------------------------------- 5.2/99.8 MB 2.2 MB/s eta 0:00:44
#    -- ------------------------------------- 5.4/99.8 MB 2.2 MB/s eta 0:00:43
#    -- ------------------------------------- 5.5/99.8 MB 2.2 MB/s eta 0:00:43
#    -- ------------------------------------- 5.7/99.8 MB 2.3 MB/s eta 0:00:42
#    -- ------------------------------------- 5.9/99.8 MB 2.3 MB/s eta 0:00:42
#    -- ------------------------------------- 6.0/99.8 MB 2.3 MB/s eta 0:00:41
#    -- ------------------------------------- 6.2/99.8 MB 2.3 MB/s eta 0:00:41
#    -- ------------------------------------- 6.4/99.8 MB 2.4 MB/s eta 0:00:40
#    -- ------------------------------------- 6.4/99.8 MB 2.4 MB/s eta 0:00:40
#    -- ------------------------------------- 6.6/99.8 MB 2.4 MB/s eta 0:00:40
#    -- ------------------------------------- 6.8/99.8 MB 2.4 MB/s eta 0:00:40
#    -- -------------------------------------
99.8 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------ --- 91.3/99.8 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------ --- 91.5/99.8 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------ --- 91.7/99.8 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------ --- 91.9/99.8 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------ --- 92.1/99.8 MB 3.8 MB/s eta 0:00:03
#    ------------------------------------ --- 92.2/99.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 92.4/99.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 92.6/99.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 92.8/99.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 92.9/99.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 93.1/99.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 93.3/99.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 93.5/99.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 93.7/99.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 93.9/99.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 94.0/99.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 94.2/99.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 94.4/99.8 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 94.6/99.8 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 94.8/99.8 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 95.0/99.8 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 95.2/99.8 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 95.3/99.8 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 95.5/99.8 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 95.7/99.8 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 95.9/99.8 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 96.1/99.8 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 96.2/99.8 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 96.4/99.8 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 96.6/99.8 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 96.8/99.8 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 97.0/99.8 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 97.1/99.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  97.3/99.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  97.3/99.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  97.3/99.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  97.3/99.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  97.7/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  97.8/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  98.0/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  98.2/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  98.4/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  98.6/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  98.8/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  99.0/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  99.1/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  99.3/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  99.5/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 99.8/99.8 MB 3.5 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.3
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('cleaned_data_v8_1.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7512\758613820.py in <module>
# ----> 1 df = pd.read_csv('cleaned_data_v8_1.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cleaned_data_v8_1.csv'

# %%
df.head()
# Out:
#            PROPERTY_TYPE           CITY  BEDROOM_NUM    AREA  BALCONY_NUM  \
# 0  Residential Apartment  Kolkata South          2.0   570.5          1.0
# 1  Residential Apartment  Kolkata South          3.0  1115.5          1.0
# 2  Residential Apartment  Kolkata South          3.0  1446.0          1.0
# 3  Residential Apartment  Kolkata South          3.0  1295.0          1.0
# 4  Residential Apartment  Kolkata South          2.0   920.0          1.0
#
#     Location  price luxury_category floor_category  age_category  \
# 0     Amtala  0.191             Low      Low Floor  Old Property
# 1  EM Bypass  1.175             Low      Low Floor  Old Property
# 2      Garia  1.285             Low      Low Floor  Old Property
# 3       Joka  0.675             Low      Low Floor  Old Property
# 4       Joka  0.470             Low      Low Floor  Old Property
#
#    Landmark_Category
# 0      Few Landmarks
# 1  Several Landmarks
# 2  Several Landmarks
# 3     Many Landmarks
# 4     Many Landmarks

# %%
X = df.drop(columns=['price'])
y = df['price']

# %%
# Applying the log1p transformation to the target variable
y_transformed = np.log1p(y)

# %%
X['AREA'] = np.log1p(X['AREA'])

# %% [markdown]
# ## Ordinal Encoding

# %%
columns_to_encode = ['CITY', 'age_category', 'luxury_category', 'floor_category','PROPERTY_TYPE','Landmark_Category']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['BEDROOM_NUM', 'AREA','BALCONY_NUM']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1', OneHotEncoder(drop='first',handle_unknown='ignore'), ['Location'])
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (0.8160093861151114, 0.017053775350858377)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['BEDROOM_NUM', 'AREA',
#                                                    'BALCONY_NUM']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['CITY', 'age_category',
#                                                    'luxury_category',
#                                                    'floor_category',
#                                                    'PROPERTY_TYPE',
#                                                    'Landmark_Category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['Location'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.26477891511719576

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))
# Out:
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 6         extra trees  0.876084  0.185103
# 5       random forest  0.867207  0.194675
# 9                 mlp  0.887584  0.197740
# 10            xgboost  0.883096  0.202123
# 1                 svr  0.878342  0.208164
# 4       decision tree  0.784206  0.232815
# 7   gradient boosting  0.846358  0.235777
# 0          linear_reg  0.816009  0.264779
# 2               ridge  0.821005  0.265261
# 8            adaboost  0.613426  0.384104
# 3               LASSO -0.002407  0.588543

# %% [markdown]
# ## One Hot Encoding

# %%
columns_to_encode = ['CITY', 'age_category', 'luxury_category', 'floor_category','PROPERTY_TYPE','Landmark_Category','Location']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['BEDROOM_NUM', 'AREA','BALCONY_NUM']),
        ('cat', OneHotEncoder(drop='first',handle_unknown='ignore'), columns_to_encode)
    ], 
    remainder='passthrough'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean()
# Out:
# 0.8095763999438976

# %%
scores.std()
# Out:
# 0.01919081228256809

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['BEDROOM_NUM', 'AREA',
#                                                    'BALCONY_NUM']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['CITY', 'age_category',
#                                                    'luxury_category',
#                                                    'floor_category',
#                                                    'PROPERTY_TYPE',
#                                                    'Landmark_Category',
#                                                    'Location'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.26456677869128614

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 6         extra trees  0.878270  0.193709
# 5       random forest  0.866696  0.197757
# 10            xgboost  0.879531  0.202463
# 1                 svr  0.885099  0.203454
# 9                 mlp  0.891293  0.203495
# 7   gradient boosting  0.842457  0.236536
# 4       decision tree  0.790031  0.244423
# 2               ridge  0.831342  0.256068
# 0          linear_reg  0.809576  0.264567
# 8            adaboost  0.693552  0.379739
# 3               LASSO -0.002407  0.588543

# %% [markdown]
# ## OneHotEncoding With PCA

# %%
columns_to_encode = ['CITY', 'age_category', 'luxury_category', 'floor_category','PROPERTY_TYPE','Landmark_Category']
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['BEDROOM_NUM', 'AREA','BALCONY_NUM']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1', OneHotEncoder(drop='first',handle_unknown='ignore',sparse_output=False), ['Location'])
    ], 
    remainder='passthrough'
)

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('pca', PCA(n_components=0.95)),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.857180  0.195354
# 6         extra trees  0.864384  0.201289
# 5       random forest  0.852634  0.210771
# 1                 svr  0.854957  0.218478
# 9                 mlp  0.857167  0.220136
# 7   gradient boosting  0.843554  0.226541
# 4       decision tree  0.710345  0.307036
# 2               ridge  0.747409  0.328563
# 0          linear_reg  0.747393  0.328595
# 8            adaboost  0.561325  0.439671
# 3               LASSO -0.002407  0.588543

# %% [markdown]
# ## Target Encoder

# %%
#!pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages (from category_encoders) (1.23.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages (from category_encoders) (1.3.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages (from category_encoders) (1.11.3)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages (from category_encoders) (0.14.1)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages (from category_encoders) (2.1.4)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages (from pandas>=1.0.5->category_encoders) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages (from pandas>=1.0.5->category_encoders) (2023.3)
# Requirement already satisfied: six in c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (3.2.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (23.2)
# Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#    ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#    --------------- ------------------------ 30.7/81.9 kB ? eta -:--:--
#    --------------- ------------------------ 30.7/81.9 kB ? eta -:--:--
#    ---------------------------------------- 81.9/81.9 kB 657.0 kB/s eta 0:00:00
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.3
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\rouna\anaconda3\envs\my_deep_learning\lib\site-packages)

# %%
import category_encoders as ce

columns_to_encode = ['luxury_category', 'floor_category','PROPERTY_TYPE','Landmark_Category']
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['BEDROOM_NUM', 'AREA','BALCONY_NUM']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1', OneHotEncoder(drop='first',handle_unknown='ignore',sparse_output=False), ['age_category']),
        ('target_enc', ce.TargetEncoder(), ['Location','CITY'])
    ], 
    remainder='passthrough'
)

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 6         extra trees  0.891581  0.179391
# 10            xgboost  0.882264  0.187359
# 5       random forest  0.877818  0.193348
# 7   gradient boosting  0.871812  0.215890
# 1                 svr  0.859694  0.221446
# 9                 mlp  0.855695  0.228363
# 4       decision tree  0.800789  0.235162
# 0          linear_reg  0.784760  0.301785
# 2               ridge  0.784798  0.301822
# 8            adaboost  0.652385  0.391002
# 3               LASSO -0.002407  0.588543

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'regressor__n_estimators': [50, 100, 200, 300,500],
    'regressor__max_depth': [None, 10, 20, 30],
    'regressor__max_samples':[0.1, 0.25, 0.5, 1.0],
    'regressor__max_features': ['auto', 'sqrt']
}

# %%
columns_to_encode = ['luxury_category', 'floor_category','PROPERTY_TYPE','Landmark_Category']
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['BEDROOM_NUM', 'AREA','BALCONY_NUM']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1', OneHotEncoder(drop='first',handle_unknown='ignore',sparse_output=False), ['age_category']),
        ('target_enc', ce.TargetEncoder(), ['Location','CITY'])
    ], 
    remainder='passthrough'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', ExtraTreesRegressor(bootstrap=True))
])

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# %%
search = GridSearchCV(pipeline, param_grid, cv=kfold, scoring='r2', n_jobs=-1, verbose=4)

# %%
search.fit(X, y_transformed)
# Out:
# Fitting 10 folds for each of 160 candidates, totalling 1600 fits
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['BEDROOM_NUM',
#                                                                           'AREA',
#                                                                           'BALCONY_NUM']),
#                                                                         ('cat',
#                                                                          OrdinalEncoder(),
#                                                                          ['luxury_category',
#                                                                           'floor_category',
#                                                                           'PROPERTY_TYPE',
#                                                                           'Landmark_Category']),
#                                                                         ('cat1',
#                                                                          OneHotEncoder(drop='...
#                                                                                        sparse_output=False),
#                                                                          ['age_category']),
#                                                                         ('target_enc',
#                                                                          TargetEncoder(),
#                                                                          ['Location',
#                                                                           'CITY'])])),
#                                        ('regressor',
#                                         ExtraTreesRegressor(bootstrap=True))]),
#              n_jobs=-1,
#              param_grid={'regressor__max_depth': [None, 10, 20, 30],
#                          'regressor__max_features': ['auto', 'sqrt'],
#                          'regressor__max_samples': [0.1, 0.25, 0.5, 1.0],
#                          'regressor__n_estimators': [50, 100, 200, 300, 500]},
#              scoring='r2', verbose=4)

# %%
final_pipe = search.best_estimator_

# %%
search.best_params_
# Out:
# {'regressor__max_depth': None,
#  'regressor__max_features': 'sqrt',
#  'regressor__max_samples': 1.0,
#  'regressor__n_estimators': 500}

# %%
search.best_score_
# Out:
# 0.8901644349226535

# %%
final_pipe.fit(X,y_transformed)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['BEDROOM_NUM', 'AREA',
#                                                    'BALCONY_NUM']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['luxury_category',
#                                                    'floor_category',
#                                                    'PROPERTY_TYPE',
#                                                    'Landmark_Category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['age_category']),
#                                                  ('target_enc', TargetEncoder(),
#                                                   ['Location', 'CITY'])])),
#                 ('regressor',
#                  ExtraTreesRegressor(bootstrap=True, max_features='sqrt',
#                                      max_samples=1.0, n_estimators=500))])

# %%
columns_to_encode = ['luxury_category', 'floor_category','PROPERTY_TYPE','Landmark_Category']
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['BEDROOM_NUM', 'AREA','BALCONY_NUM']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1', OneHotEncoder(drop='first',handle_unknown='ignore',sparse_output=False), ['age_category']),
        ('target_enc', ce.TargetEncoder(), ['Location','CITY'])
    ], 
    remainder='passthrough'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', ExtraTreesRegressor(n_estimators = 500))
])

X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['BEDROOM_NUM', 'AREA',
#                                                    'BALCONY_NUM']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['luxury_category',
#                                                    'floor_category',
#                                                    'PROPERTY_TYPE',
#                                                    'Landmark_Category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['age_category']),
#                                                  ('target_enc', TargetEncoder(),
#                                                   ['Location', 'CITY'])])),
#                 ('regressor', ExtraTreesRegressor(n_estimators=500))])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.1795084198629146

# %% [markdown]
# ## Trying Out Predictions

# %%
X.columns
# Out:
# Index(['PROPERTY_TYPE', 'CITY', 'BEDROOM_NUM', 'AREA', 'BALCONY_NUM',
#        'Location', 'luxury_category', 'floor_category', 'age_category',
#        'Landmark_Category'],
#       dtype='object')

# %%
X.iloc[0].values
# Out:
# array(['Residential Apartment', 'Kolkata South', 2.0, 570.5, 1.0,
#        'Amtala', 'Low', 'Low Floor', 'Old Property', 'Few Landmarks'],
#       dtype=object)

# %%
data = [['Residential Apartment', 'Kolkata South', 3.0, 1750, 3.0, 'Amtala', 'Low', 'Low Floor', 'Old Property', 'Few Landmarks']]
columns = ['PROPERTY_TYPE', 'CITY', 'BEDROOM_NUM', 'AREA', 'BALCONY_NUM',
       'Location', 'luxury_category', 'floor_category', 'age_category',
       'Landmark_Category']

# Convert to DataFrame
one_df = pd.DataFrame(data, columns=columns)

one_df
# Out:
#            PROPERTY_TYPE           CITY  BEDROOM_NUM  AREA  BALCONY_NUM  \
# 0  Residential Apartment  Kolkata South          3.0  1750          3.0
#
#   Location luxury_category floor_category  age_category Landmark_Category
# 0   Amtala             Low      Low Floor  Old Property     Few Landmarks

# %%
np.expm1(pipeline.predict(one_df))
# Out:
# array([0.84376046])

# %%
import pickle

with open('pipeline.pkl', 'wb') as file:
    pickle.dump(pipeline, file)

# %%
with open('df.pkl', 'wb') as file:
    pickle.dump(X, file)

# %%
import pickle

# %%
with open('df.pkl','rb') as file:
    df = pickle.load(file)

# %%
df[df['CITY'] == 'Kolkata North']['Location'].unique().tolist()
# Out:
# ['Madhyamgram',
#  'Narkeldanga',
#  'BT Road',
#  'Bangur',
#  'Dum Dum',
#  'Kestopur',
#  'Dum Dum Park',
#  'Barasat',
#  'Belgharia',
#  'Ultadanga',
#  'Salt Lake',
#  'Nager Bazar',
#  'Baguiati',
#  'Dunlop',
#  'Durganagar',
#  'Kanchrapara',
#  'Noapara',
#  'Maniktala',
#  'New Barrakpur',
#  'Sodepur',
#  'Kaikhali',
#  'Badu',
#  'Lake Town',
#  'Sinthi More',
#  'Sector 3 Salt Lake',
#  'Birati',
#  'Nalta',
#  'Shobhabazar',
#  'Beliaghata',
#  'Kankurgachi',
#  'Jyangra',
#  'Amarpalli',
#  'Deshpriya Nagar',
#  'Hanapara',
#  'Ichapore',
#  'Debpukur',
#  'Airport',
#  'Jessore road Ganga Nagar',
#  'Barrackpore',
#  'Barat Colony',
#  'Badamtala',
#  'Raghunathpur',
#  'Paikpara',
#  'Rathtala',
#  'Srirampur',
#  'Teghoria',
#  'Kalindi',
#  'Dum Dum Cantt',
#  'VIP Haldiram',
#  'EM Bypass',
#  'Jessore Road',
#  'Sukchar',
#  'Girish Park',
#  'Khardah',
#  'Phoolbagan',
#  'Ananya',
#  '5/1B MM Feeder Road.Kolkata-700057',
#  'Garpar',
#  'Bhatpara',
#  'Jheel Bagan',
#  'Khalisha Kota',
#  'Sector 1 Salt Lake',
#  'Nimta',
#  'South Sinthee',
#  'Shyamnagar 24 pgs north',
#  'Sinthee',
#  'Nandan Nagar',
#  'Dutta Bagan',
#  'Gorabazar',
#  'Prafulla Kanan',
#  'Ariadaha',
#  'Shyamnagar',
#  'Dakshinpara',
#  'Dakshineswar',
#  'Naihati',
#  'Bara Nagar',
#  'Nona Chandanpukur',
#  'Kalyani',
#  'Dum Dum Metro',
#  'Kankinara',
#  'Cossipore',
#  'Sector 5 Salt Lake',
#  'Ramgarh',
#  'Anandapuri',
#  'Sector 2 Salt Lake',
#  'Tobin Road',
#  'Panihati',
#  'Agarpara',
#  'Tetultala',
#  'Shyam Nagar',
#  'Michael Nagar',
#  'Madhyamgram, Doltala',
#  'BT collage, Jessore road',
#  'Michael nagar, Birati',
#  'Bonhooghly',
#  'Satgachi',
#  'HB Town',
#  'kalyani a block',
#  'Gola Ghata',
#  'Gora Bazar',
#  'Vivekananda Nagar',
#  'Baguihati',
#  'Shyam Bazaar',
#  'telipukur',
#  'Sinthi',
#  'Basunagar',
#  'Atghara',
#  'Surer Math',
#  'Narayanpur',
#  'Hridaypur',
#  'Seth Bagan',
#  'Natunbazar.dumdum cantonment',
#  'Purbachal',
#  'baguihati jyangra',
#  'BANGUR AVENUE',
#  'Alipore',
#  'South Bankimpally',
#  'Belgachia',
#  'Lake Town/kalindi',
#  'Sabedabagan',
#  'Zarda Bagan',
#  'Khanna',
#  'Subhash Nagar',
#  'Block C, Bangur',
#  'VIP Road',
#  'Matkol',
#  'Biman Nagar']
